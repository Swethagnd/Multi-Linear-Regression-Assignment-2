# %% [markdown]
# # Consider only the below columns and prepare a prediction model for predicting Price.
#
# Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.stats.tests.test_influence
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# import dataset
toyota1=pd.read_csv('ToyotaCorolla.csv',encoding='latin1')
toyota1
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
toyota1.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Color', 'Automatic', 'cc', 'Doors',
#        'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee',
#        'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2',
#        'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player',
#        'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio',
#        'Mistlamps', 'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
#        'Radio_cassette', 'Tow_Bar'],
#       dtype='object')

# %%
toyota1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
toyota1.shape
# Out:
# (1436, 38)

# %%
toyota2=toyota1[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
toyota2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
toyota2.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
toyota2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
# renaming names for convenient
toyota3=toyota2.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
toyota3.head()
# Out:
#    Price  Age     KM  HP    CC  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
toyota3.isna().sum() # there is no 0 values in a data set
# Out:
# Price     0
# Age       0
# KM        0
# HP        0
# CC        0
# Doors     0
# Gears     0
# QT        0
# Weight    0
# dtype: int64

# %% [markdown]
# # checking for duplicates

# %%
toyota3[toyota3.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 113  24950    8  13253  116  2000      5      5  234    1320

# %%
toyota4=toyota3.drop_duplicates().reset_index(drop=True)
toyota4
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
toyota4.describe()
# Out:
#               Price          Age             KM           HP            CC  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears           QT       Weight
# count  1435.000000  1435.000000  1435.000000  1435.000000
# mean      4.032753     5.026481    87.020209  1072.287108
# std       0.952667     0.188575    40.959588    52.251882
# min       2.000000     3.000000    19.000000  1000.000000
# ...

# %% [markdown]
# # Correlation Analysis

# %%
corrMatrix=toyota4.corr()
corrMatrix
# Out:
#            Price       Age        KM        HP        CC     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# CC      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT      0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#               QT    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# CC      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(toyota4)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corrMatrix, annot = True,fmt=".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Building

# %%
model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota4).fit()

# %%
#finding coefficient parameters
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):               0.00
# Time:                        19:00:14   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5472.5404   1412.169     -3.875      0.000   -8242.692   -2702.389
# ...

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept    -3.875273
# Age         -46.551876
# KM          -16.552424
# HP           11.209719
# CC           -1.316436
# Doors        -0.023012
# Gears         3.034563
# QT            2.944198
# Weight       15.760663
# dtype: float64
#  Intercept     1.113392e-04
# Age          1.879217e-288
# KM            1.994713e-56
# HP            5.211155e-28
# CC            1.882393e-01
# Doors         9.816443e-01
# Gears         2.452430e-03
# QT            3.290363e-03
# Weight        1.031118e-51
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8625200256947, 0.8617487495415146)

# %% [markdown]
# # Multi-Collinearity and Handling Multi-Collinearity

# %% [markdown]
# # Residual Analysis

# %% [markdown]
# Test for Normality of Residuals

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))  # outliar detection from above QQ plot of residuals
# Out:
# [array([109, 146, 522], dtype=int64)]

# %%
list(np.where(model.resid<-6000))  # outliar detection from above QQ plot of residuals
# Out:
# [array([220, 600, 959], dtype=int64)]

# %% [markdown]
# # Residual Plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# # Residual Vs Regressors

# %%
fig = plt.figure(figsize=(12,12))
fig = sm.graphics.plot_regress_exog(model, "Age", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(12,12))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(12,12))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(12,12))
fig = sm.graphics.plot_regress_exog(model, "CC", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "QT", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics

# %% [markdown]
# Detecting Influencers/Outliers

# %% [markdown]
# Cook’s Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(toyota4)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than 70
(np.argmax(c),np.max(c))
# Out:
# (80, 78.72950582248198)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = 4 
n = toyota4.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.010452961672473868

# %% [markdown]
# # From the above plot, it is evident that data point 80 are the influencers

# %% [markdown]
# # VIF

# %%
rsq_Age = smf.ols('Age~KM+HP+CC+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared  
vif_Age = 1/(1-rsq_Age) 

rsq_KM = smf.ols('KM~Age+HP+CC+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared  
vif_KM = 1/(1-rsq_KM) 

rsq_HP = smf.ols('HP~KM+Age+CC+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared  
vif_HP = 1/(1-rsq_HP) 

rsq_CC = smf.ols('CC~KM+HP+Age+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared  
vif_CC = 1/(1-rsq_CC) 

rsq_Doors = smf.ols('Doors~KM+HP+CC+Age+Gears+QT+Weight',data=toyota4).fit().rsquared  
vif_Doors = 1/(1-rsq_Doors) 

rsq_Gears= smf.ols('Gears~KM+HP+CC+Doors+Age+QT+Weight',data=toyota4).fit().rsquared  
vif_Gears= 1/(1-rsq_Gears) 

rsq_QT= smf.ols('QT~KM+HP+CC+Doors+Gears+Age+Weight',data=toyota4).fit().rsquared  
vif_QT = 1/(1-rsq_QT) 

rsq_Weight = smf.ols('Weight~KM+HP+CC+Doors+Gears+QT+Age',data=toyota4).fit().rsquared  
vif_Weight = 1/(1-rsq_Weight) 


# Storing vif values in a data frame
d1 = {'Variables':['Age','KM','HP','CC','Doors','Gears','QT','Weight'],'VIF':[vif_Age,vif_KM,vif_HP,vif_CC,vif_Doors,vif_Gears,vif_QT,vif_Weight]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables       VIF
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        CC  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %% [markdown]
# As per VIf Values are high for QT and Weight

# %% [markdown]
# # Model Deletion Diagnostics and Final Model

# %%
# Removing Weight and predicting the model
model_w = smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT',data=toyota4).fit()
new_predictions =model_w.predict(toyota4)

# %%
model_w.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     1059.
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):               0.00
# Time:                        20:11:25   Log-Likelihood:                -12481.
# No. Observations:                1435   AIC:                         2.498e+04
# Df Residuals:                    1427   BIC:                         2.502e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9990.3469   1100.231      9.080      0.000    7832.103    1.21e+04
# ...

# %%
# Removing QT and predicting the model
model_q = smf.ols('Price~Age+KM+HP+CC+Doors+Gears+Weight',data=toyota4).fit()
new_predictions1 = model_q.predict(toyota4)

# %%
model_q.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     1270.
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):               0.00
# Time:                        20:12:03   Log-Likelihood:                -12371.
# No. Observations:                1435   AIC:                         2.476e+04
# Df Residuals:                    1427   BIC:                         2.480e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6969.4756   1321.000     -5.276      0.000   -9560.786   -4378.165
# ...

# %%
# Removing QT and Weight predicting the model
model_wq = smf.ols('Price~Age+KM+HP+CC+Doors+Gears',data=toyota4).fit()
new_predictions2 = model_wq.predict(toyota4)

# %%
model_wq.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     1062.
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):               0.00
# Time:                        20:12:12   Log-Likelihood:                -12572.
# No. Observations:                1435   AIC:                         2.516e+04
# Df Residuals:                    1428   BIC:                         2.519e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.119e+04   1167.571      9.582      0.000    8897.584    1.35e+04
# ...

# %% [markdown]
# # Model Deletion Diagnoatics

# %%
# cooks distance removing index 80..
toyota4[toyota4.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %%
#Compare and other variable values
toyota4.head()
# Out:
#    Price  Age     KM  HP    CC  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
(model.rsquared,model.aic)
# Out:
# (0.8625200256947, 24750.407207346932)

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
toyota5=toyota4.drop(toyota4.index[[80]],axis=0).reset_index()

# %%
#Drop the original index
toyota5=toyota5.drop(['index'],axis=1)
toyota5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1429   7500   69  20544   86  1300      3      5   69    1025
# 1430  10845   72  19000   86  1300      3      5   69    1015
# 1431   8500   71  17016   86  1300      3      5   69    1015
# 1432   7250   70  16916   86  1300      3      5   69    1015
# 1433   6950   76      1  110  1600      5      5   19    1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# # Final Model

# %%
# By the above predictions removing Weight form df
X = toyota5[['Age','KM','HP','CC','Doors','Gears','QT']]
Y = toyota5[['Price']]

# %%
final_model = sm.OLS(Y, X).fit()
predictions = final_model.predict(X)

# %%
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared (uncentered):                   0.983
# Model:                            OLS   Adj. R-squared (uncentered):              0.983
# Method:                 Least Squares   F-statistic:                          1.151e+04
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):                        0.00
# Time:                        20:12:44   Log-Likelihood:                         -12513.
# No. Observations:                1434   AIC:                                  2.504e+04
# Df Residuals:                    1427   BIC:                                  2.508e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Output  Prediction

# %% [markdown]
# 1 - p-value < 0.01
# Thus the model is accepted
#
# 2 - coefficient == -132.01
# Thus if the value of x increased by 1, the predicted value of Price will decrease by 132.01
#
# 3 - Adj. R-sqared == 0.983
# Thus the model explains 98.3% of the variance in dependent variable
